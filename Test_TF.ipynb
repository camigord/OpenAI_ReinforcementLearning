# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
gpu_config = tf.ConfigProto()
gpu_config.gpu_options.allow_growth = True
gpu_config.gpu_options.per_process_gpu_memory_fraction = 1.0
gpu_config.log_device_placement = True

# Launch the graph
with tf.Session(config=gpu_config) as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 23986.890625, Training Accuracy= 0.26562
# Iter 2560, Minibatch Loss= 13750.960938, Training Accuracy= 0.46094
# Iter 3840, Minibatch Loss= 7074.712891, Training Accuracy= 0.63281
# Iter 5120, Minibatch Loss= 4124.677734, Training Accuracy= 0.70312
# Iter 6400, Minibatch Loss= 4550.300293, Training Accuracy= 0.75781
# Iter 7680, Minibatch Loss= 5718.410645, Training Accuracy= 0.71094
# Iter 8960, Minibatch Loss= 3512.507324, Training Accuracy= 0.83594
# Iter 10240, Minibatch Loss= 2785.958740, Training Accuracy= 0.79688
# Iter 11520, Minibatch Loss= 1534.684814, Training Accuracy= 0.89844
# Iter 12800, Minibatch Loss= 3306.627930, Training Accuracy= 0.83594
# Iter 14080, Minibatch Loss= 1380.532471, Training Accuracy= 0.88281
# Iter 15360, Minibatch Loss= 983.785278, Training Accuracy= 0.89062
# Iter 16640, Minibatch Loss= 2837.561035, Training Accuracy= 0.88281
# Iter 17920, Minibatch Loss= 1026.318237, Training Accuracy= 0.89844
# Iter 19200, Minibatch Loss= 929.196533, Training Accuracy= 0.92188
# Iter 20480, Minibatch Loss= 235.435593, Training Accuracy= 0.96094
# Iter 21760, Minibatch Loss= 2636.583008, Training Accuracy= 0.87500
# Iter 23040, Minibatch Loss= 763.162964, Training Accuracy= 0.94531
# Iter 24320, Minibatch Loss= 1280.932739, Training Accuracy= 0.89844
# Iter 25600, Minibatch Loss= 815.292236, Training Accuracy= 0.92188
# Iter 26880, Minibatch Loss= 956.347290, Training Accuracy= 0.91406
# Iter 28160, Minibatch Loss= 1197.569946, Training Accuracy= 0.89844
# Iter 29440, Minibatch Loss= 1722.324951, Training Accuracy= 0.91406
# Iter 30720, Minibatch Loss= 882.982300, Training Accuracy= 0.92188
# Iter 32000, Minibatch Loss= 1033.303223, Training Accuracy= 0.93750
# Iter 33280, Minibatch Loss= 728.149902, Training Accuracy= 0.93750
# Iter 34560, Minibatch Loss= 630.914185, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 591.320068, Training Accuracy= 0.95312
# Iter 37120, Minibatch Loss= 1591.978027, Training Accuracy= 0.93750
# Iter 38400, Minibatch Loss= 195.758621, Training Accuracy= 0.98438
# Iter 39680, Minibatch Loss= 446.804871, Training Accuracy= 0.93750
# Iter 40960, Minibatch Loss= 1129.415771, Training Accuracy= 0.92188
# Iter 42240, Minibatch Loss= 291.667236, Training Accuracy= 0.97656
# Iter 43520, Minibatch Loss= 330.051422, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 325.094482, Training Accuracy= 0.95312
# Iter 46080, Minibatch Loss= 208.759857, Training Accuracy= 0.96875
# Iter 47360, Minibatch Loss= 843.302124, Training Accuracy= 0.92969
# Iter 48640, Minibatch Loss= 965.240051, Training Accuracy= 0.93750
# Iter 49920, Minibatch Loss= 867.591553, Training Accuracy= 0.90625
# Iter 51200, Minibatch Loss= 666.260376, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 148.558502, Training Accuracy= 0.98438
# Iter 53760, Minibatch Loss= 158.845673, Training Accuracy= 0.97656
# Iter 55040, Minibatch Loss= 442.379761, Training Accuracy= 0.95312
# Iter 56320, Minibatch Loss= 409.920135, Training Accuracy= 0.94531
# Iter 57600, Minibatch Loss= 983.822876, Training Accuracy= 0.89844
# Iter 58880, Minibatch Loss= 539.277161, Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 513.539551, Training Accuracy= 0.92969
# Iter 61440, Minibatch Loss= 336.079071, Training Accuracy= 0.94531
# Iter 62720, Minibatch Loss= 1552.858643, Training Accuracy= 0.91406
# Iter 64000, Minibatch Loss= 635.805847, Training Accuracy= 0.94531
# Iter 65280, Minibatch Loss= 534.976440, Training Accuracy= 0.95312
# Iter 66560, Minibatch Loss= 793.832214, Training Accuracy= 0.91406
# Iter 67840, Minibatch Loss= 289.845306, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 209.085022, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 927.017944, Training Accuracy= 0.93750
# Iter 71680, Minibatch Loss= 515.283569, Training Accuracy= 0.92969
# Iter 72960, Minibatch Loss= 167.298340, Training Accuracy= 0.97656
# Iter 74240, Minibatch Loss= 473.174988, Training Accuracy= 0.94531
# Iter 75520, Minibatch Loss= 34.289719, Training Accuracy= 0.98438
# Iter 76800, Minibatch Loss= 451.800140, Training Accuracy= 0.93750
# Iter 78080, Minibatch Loss= 472.399445, Training Accuracy= 0.92969
# Iter 79360, Minibatch Loss= 627.529785, Training Accuracy= 0.92969
# Iter 80640, Minibatch Loss= 489.158691, Training Accuracy= 0.95312
# Iter 81920, Minibatch Loss= 433.602783, Training Accuracy= 0.96094
# Iter 83200, Minibatch Loss= 272.970490, Training Accuracy= 0.95312
# Iter 84480, Minibatch Loss= 668.101379, Training Accuracy= 0.94531
# Iter 85760, Minibatch Loss= 534.449768, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 385.859833, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 171.964645, Training Accuracy= 0.96094
# Iter 89600, Minibatch Loss= 405.231201, Training Accuracy= 0.96875
# Iter 90880, Minibatch Loss= 5.473618, Training Accuracy= 0.99219
# Iter 92160, Minibatch Loss= 453.037842, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 726.959229, Training Accuracy= 0.92969
# Iter 94720, Minibatch Loss= 634.039429, Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 247.596115, Training Accuracy= 0.96094
# Iter 97280, Minibatch Loss= 377.920380, Training Accuracy= 0.93750
# Iter 98560, Minibatch Loss= 25.709534, Training Accuracy= 0.99219
# Iter 99840, Minibatch Loss= 516.550293, Training Accuracy= 0.95312
# Iter 101120, Minibatch Loss= 576.785400, Training Accuracy= 0.96094
# Iter 102400, Minibatch Loss= 415.230652, Training Accuracy= 0.94531
# Iter 103680, Minibatch Loss= 410.435486, Training Accuracy= 0.95312
# Iter 104960, Minibatch Loss= 657.892639, Training Accuracy= 0.96094
# Iter 106240, Minibatch Loss= 389.897583, Training Accuracy= 0.96094
# Iter 107520, Minibatch Loss= 490.259521, Training Accuracy= 0.95312
# Iter 108800, Minibatch Loss= 755.355713, Training Accuracy= 0.94531
# Iter 110080, Minibatch Loss= 441.536865, Training Accuracy= 0.95312
# Iter 111360, Minibatch Loss= 110.318993, Training Accuracy= 0.98438
# Iter 112640, Minibatch Loss= 293.580353, Training Accuracy= 0.96875
# Iter 113920, Minibatch Loss= 183.163239, Training Accuracy= 0.96875
# Iter 115200, Minibatch Loss= 338.948486, Training Accuracy= 0.97656
# Iter 116480, Minibatch Loss= 348.685913, Training Accuracy= 0.94531
# Iter 117760, Minibatch Loss= 239.295181, Training Accuracy= 0.96094
# Iter 119040, Minibatch Loss= 161.976166, Training Accuracy= 0.97656
# Iter 120320, Minibatch Loss= 265.240723, Training Accuracy= 0.95312
# Iter 121600, Minibatch Loss= 38.839981, Training Accuracy= 0.99219
# Iter 122880, Minibatch Loss= 333.344757, Training Accuracy= 0.96875
# Iter 124160, Minibatch Loss= 505.970215, Training Accuracy= 0.96875
# Iter 125440, Minibatch Loss= 272.499268, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 79.101768, Training Accuracy= 0.98438
# Iter 128000, Minibatch Loss= 61.025803, Training Accuracy= 0.99219
# Iter 129280, Minibatch Loss= 251.143707, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 148.455536, Training Accuracy= 0.97656
# Iter 131840, Minibatch Loss= 16.039795, Training Accuracy= 0.98438
# Iter 133120, Minibatch Loss= 173.566589, Training Accuracy= 0.96875
# Iter 134400, Minibatch Loss= 293.873596, Training Accuracy= 0.93750
# Iter 135680, Minibatch Loss= 41.390526, Training Accuracy= 0.98438
# Iter 136960, Minibatch Loss= 68.483917, Training Accuracy= 0.96875
# Iter 138240, Minibatch Loss= 182.963470, Training Accuracy= 0.96875
# Iter 139520, Minibatch Loss= 150.583282, Training Accuracy= 0.97656
# Iter 140800, Minibatch Loss= 377.123383, Training Accuracy= 0.96875
# Iter 142080, Minibatch Loss= 119.041321, Training Accuracy= 0.98438
# Iter 143360, Minibatch Loss= 228.363419, Training Accuracy= 0.96094
# Iter 144640, Minibatch Loss= 33.590607, Training Accuracy= 0.99219
# Iter 145920, Minibatch Loss= 546.622375, Training Accuracy= 0.95312
# Iter 147200, Minibatch Loss= 218.571228, Training Accuracy= 0.96094
# Iter 148480, Minibatch Loss= 79.053238, Training Accuracy= 0.98438
# Iter 149760, Minibatch Loss= 258.577454, Training Accuracy= 0.96094
# Iter 151040, Minibatch Loss= 321.018738, Training Accuracy= 0.96094
# Iter 152320, Minibatch Loss= 229.131439, Training Accuracy= 0.96875
# Iter 153600, Minibatch Loss= 408.513519, Training Accuracy= 0.96875
# Iter 154880, Minibatch Loss= 179.896454, Training Accuracy= 0.95312
# Iter 156160, Minibatch Loss= 179.213409, Training Accuracy= 0.96094
# Iter 157440, Minibatch Loss= 92.245850, Training Accuracy= 0.97656
# Iter 158720, Minibatch Loss= 18.276840, Training Accuracy= 0.99219
# Iter 160000, Minibatch Loss= 125.986938, Training Accuracy= 0.99219
# Iter 161280, Minibatch Loss= 338.307556, Training Accuracy= 0.96875
# Iter 162560, Minibatch Loss= 57.125633, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 75.064522, Training Accuracy= 0.98438
# Iter 165120, Minibatch Loss= 210.262238, Training Accuracy= 0.95312
# Iter 166400, Minibatch Loss= 113.071396, Training Accuracy= 0.98438
# Iter 167680, Minibatch Loss= 58.171375, Training Accuracy= 0.99219
# Iter 168960, Minibatch Loss= 93.674385, Training Accuracy= 0.98438
# Iter 170240, Minibatch Loss= 282.198395, Training Accuracy= 0.96875
# Iter 171520, Minibatch Loss= 11.340141, Training Accuracy= 0.99219
# Iter 172800, Minibatch Loss= 269.974487, Training Accuracy= 0.96094
# Iter 174080, Minibatch Loss= 105.081924, Training Accuracy= 0.97656
# Iter 175360, Minibatch Loss= 342.048340, Training Accuracy= 0.96875
# Iter 176640, Minibatch Loss= 105.205780, Training Accuracy= 0.97656
# Iter 177920, Minibatch Loss= 82.795517, Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 264.596313, Training Accuracy= 0.97656
# Iter 180480, Minibatch Loss= 104.368675, Training Accuracy= 0.96875
# Iter 181760, Minibatch Loss= 201.497986, Training Accuracy= 0.96875
# Iter 183040, Minibatch Loss= 181.197769, Training Accuracy= 0.97656
# Iter 184320, Minibatch Loss= 47.100502, Training Accuracy= 0.99219
# Iter 185600, Minibatch Loss= 204.110474, Training Accuracy= 0.95312
# Iter 186880, Minibatch Loss= 182.679443, Training Accuracy= 0.96094
# Iter 188160, Minibatch Loss= 120.793686, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 150.899399, Training Accuracy= 0.96875
# Iter 190720, Minibatch Loss= 179.435394, Training Accuracy= 0.97656
# Iter 192000, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 193280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 194560, Minibatch Loss= 159.084030, Training Accuracy= 0.99219
# Iter 195840, Minibatch Loss= 89.935280, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 189.758667, Training Accuracy= 0.96094
# Iter 198400, Minibatch Loss= 162.815948, Training Accuracy= 0.95312
# Iter 199680, Minibatch Loss= 61.165169, Training Accuracy= 0.97656
# Optimization Finished!
# Testing Accuracy: 0.992188
