# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
gpu_config = tf.ConfigProto()
gpu_config.gpu_options.allow_growth = True
gpu_config.gpu_options.per_process_gpu_memory_fraction = 1.0
gpu_config.log_device_placement = True

# Launch the graph
with tf.Session(config=gpu_config) as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 38321.453125, Training Accuracy= 0.16406
# Iter 2560, Minibatch Loss= 13202.156250, Training Accuracy= 0.41406
# Iter 3840, Minibatch Loss= 12335.885742, Training Accuracy= 0.53125
# Iter 5120, Minibatch Loss= 6678.180664, Training Accuracy= 0.65625
# Iter 6400, Minibatch Loss= 3869.221924, Training Accuracy= 0.74219
# Iter 7680, Minibatch Loss= 8334.619141, Training Accuracy= 0.72656
# Iter 8960, Minibatch Loss= 3939.856445, Training Accuracy= 0.77344
# Iter 10240, Minibatch Loss= 2533.202637, Training Accuracy= 0.82812
# Iter 11520, Minibatch Loss= 2276.175293, Training Accuracy= 0.86719
# Iter 12800, Minibatch Loss= 3678.616699, Training Accuracy= 0.81250
# Iter 14080, Minibatch Loss= 1250.911377, Training Accuracy= 0.89062
# Iter 15360, Minibatch Loss= 1136.477051, Training Accuracy= 0.94531
# Iter 16640, Minibatch Loss= 2179.547852, Training Accuracy= 0.86719
# Iter 17920, Minibatch Loss= 532.793945, Training Accuracy= 0.94531
# Iter 19200, Minibatch Loss= 1387.704590, Training Accuracy= 0.90625
# Iter 20480, Minibatch Loss= 838.556213, Training Accuracy= 0.93750
# Iter 21760, Minibatch Loss= 2876.811279, Training Accuracy= 0.85938
# Iter 23040, Minibatch Loss= 815.650696, Training Accuracy= 0.95312
# Iter 24320, Minibatch Loss= 1528.170410, Training Accuracy= 0.88281
# Iter 25600, Minibatch Loss= 1278.575195, Training Accuracy= 0.87500
# Iter 26880, Minibatch Loss= 1370.055420, Training Accuracy= 0.91406
# Iter 28160, Minibatch Loss= 1384.086792, Training Accuracy= 0.92188
# Iter 29440, Minibatch Loss= 1105.414917, Training Accuracy= 0.91406
# Iter 30720, Minibatch Loss= 983.393555, Training Accuracy= 0.92969
# Iter 32000, Minibatch Loss= 965.674927, Training Accuracy= 0.92969
# Iter 33280, Minibatch Loss= 1383.803467, Training Accuracy= 0.89844
# Iter 34560, Minibatch Loss= 914.937927, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 622.180298, Training Accuracy= 0.96875
# Iter 37120, Minibatch Loss= 1189.226562, Training Accuracy= 0.92188
# Iter 38400, Minibatch Loss= 197.180328, Training Accuracy= 0.97656
# Iter 39680, Minibatch Loss= 457.716309, Training Accuracy= 0.96094
# Iter 40960, Minibatch Loss= 1576.892456, Training Accuracy= 0.89844
# Iter 42240, Minibatch Loss= 1008.102966, Training Accuracy= 0.92188
# Iter 43520, Minibatch Loss= 349.271210, Training Accuracy= 0.96875
# Iter 44800, Minibatch Loss= 488.059570, Training Accuracy= 0.95312
# Iter 46080, Minibatch Loss= 274.926636, Training Accuracy= 0.97656
# Iter 47360, Minibatch Loss= 844.305908, Training Accuracy= 0.96094
# Iter 48640, Minibatch Loss= 796.095825, Training Accuracy= 0.95312
# Iter 49920, Minibatch Loss= 741.920044, Training Accuracy= 0.91406
# Iter 51200, Minibatch Loss= 468.737762, Training Accuracy= 0.96875
# Iter 52480, Minibatch Loss= 179.632202, Training Accuracy= 0.97656
# Iter 53760, Minibatch Loss= 102.738174, Training Accuracy= 0.96875
# Iter 55040, Minibatch Loss= 449.925598, Training Accuracy= 0.96094
# Iter 56320, Minibatch Loss= 611.566833, Training Accuracy= 0.95312
# Iter 57600, Minibatch Loss= 468.062866, Training Accuracy= 0.93750
# Iter 58880, Minibatch Loss= 1270.987793, Training Accuracy= 0.92188
# Iter 60160, Minibatch Loss= 999.238770, Training Accuracy= 0.90625
# Iter 61440, Minibatch Loss= 1093.690918, Training Accuracy= 0.93750
# Iter 62720, Minibatch Loss= 823.536621, Training Accuracy= 0.95312
# Iter 64000, Minibatch Loss= 654.817383, Training Accuracy= 0.93750
# Iter 65280, Minibatch Loss= 407.247375, Training Accuracy= 0.93750
# Iter 66560, Minibatch Loss= 233.097443, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 819.852417, Training Accuracy= 0.94531
# Iter 69120, Minibatch Loss= 828.197998, Training Accuracy= 0.92969
# Iter 70400, Minibatch Loss= 402.370728, Training Accuracy= 0.97656
# Iter 71680, Minibatch Loss= 578.879639, Training Accuracy= 0.95312
# Iter 72960, Minibatch Loss= 85.640282, Training Accuracy= 0.96875
# Iter 74240, Minibatch Loss= 521.060059, Training Accuracy= 0.94531
# Iter 75520, Minibatch Loss= 137.322235, Training Accuracy= 0.96875
# Iter 76800, Minibatch Loss= 270.479706, Training Accuracy= 0.96094
# Iter 78080, Minibatch Loss= 825.547607, Training Accuracy= 0.95312
# Iter 79360, Minibatch Loss= 115.497284, Training Accuracy= 0.97656
# Iter 80640, Minibatch Loss= 639.431824, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 838.275391, Training Accuracy= 0.94531
# Iter 83200, Minibatch Loss= 475.814484, Training Accuracy= 0.96094
# Iter 84480, Minibatch Loss= 224.785675, Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 152.797775, Training Accuracy= 0.96875
# Iter 87040, Minibatch Loss= 893.504211, Training Accuracy= 0.94531
# Iter 88320, Minibatch Loss= 312.151886, Training Accuracy= 0.93750
# Iter 89600, Minibatch Loss= 309.438171, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 92160, Minibatch Loss= 568.906677, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 532.749146, Training Accuracy= 0.96094
# Iter 94720, Minibatch Loss= 378.107819, Training Accuracy= 0.96094
# Iter 96000, Minibatch Loss= 27.388840, Training Accuracy= 0.98438
# Iter 97280, Minibatch Loss= 85.174835, Training Accuracy= 0.99219
# Iter 98560, Minibatch Loss= 77.537872, Training Accuracy= 0.97656
# Iter 99840, Minibatch Loss= 228.975342, Training Accuracy= 0.96094
# Iter 101120, Minibatch Loss= 101.919746, Training Accuracy= 0.97656
# Iter 102400, Minibatch Loss= 112.245392, Training Accuracy= 0.99219
# Iter 103680, Minibatch Loss= 438.243317, Training Accuracy= 0.96094
# Iter 104960, Minibatch Loss= 186.493622, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 250.806656, Training Accuracy= 0.96875
# Iter 107520, Minibatch Loss= 600.207214, Training Accuracy= 0.94531
# Iter 108800, Minibatch Loss= 450.800415, Training Accuracy= 0.96094
# Iter 110080, Minibatch Loss= 312.987549, Training Accuracy= 0.96875
# Iter 111360, Minibatch Loss= 183.131180, Training Accuracy= 0.97656
# Iter 112640, Minibatch Loss= 324.747681, Training Accuracy= 0.93750
# Iter 113920, Minibatch Loss= 382.506836, Training Accuracy= 0.97656
# Iter 115200, Minibatch Loss= 366.090088, Training Accuracy= 0.98438
# Iter 116480, Minibatch Loss= 163.053833, Training Accuracy= 0.94531
# Iter 117760, Minibatch Loss= 255.547424, Training Accuracy= 0.96875
# Iter 119040, Minibatch Loss= 122.344902, Training Accuracy= 0.97656
# Iter 120320, Minibatch Loss= 203.014923, Training Accuracy= 0.96094
# Iter 121600, Minibatch Loss= 500.310547, Training Accuracy= 0.94531
# Iter 122880, Minibatch Loss= 621.458374, Training Accuracy= 0.96094
# Iter 124160, Minibatch Loss= 426.787018, Training Accuracy= 0.97656
# Iter 125440, Minibatch Loss= 538.854248, Training Accuracy= 0.94531
# Iter 126720, Minibatch Loss= 223.073166, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 379.320740, Training Accuracy= 0.96875
# Iter 129280, Minibatch Loss= 312.610229, Training Accuracy= 0.96094
# Iter 130560, Minibatch Loss= 242.310684, Training Accuracy= 0.96875
# Iter 131840, Minibatch Loss= 233.655289, Training Accuracy= 0.96875
# Iter 133120, Minibatch Loss= 685.341003, Training Accuracy= 0.92188
# Iter 134400, Minibatch Loss= 50.204651, Training Accuracy= 0.99219
# Iter 135680, Minibatch Loss= 379.917328, Training Accuracy= 0.96094
# Iter 136960, Minibatch Loss= 357.426941, Training Accuracy= 0.96094
# Iter 138240, Minibatch Loss= 235.102188, Training Accuracy= 0.95312
# Iter 139520, Minibatch Loss= 106.006973, Training Accuracy= 0.99219
# Iter 140800, Minibatch Loss= 148.012451, Training Accuracy= 0.98438
# Iter 142080, Minibatch Loss= 66.761902, Training Accuracy= 0.98438
# Iter 143360, Minibatch Loss= 301.832611, Training Accuracy= 0.98438
# Iter 144640, Minibatch Loss= 324.535034, Training Accuracy= 0.95312
# Iter 145920, Minibatch Loss= 514.174316, Training Accuracy= 0.96875
# Iter 147200, Minibatch Loss= 90.670456, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 151.507935, Training Accuracy= 0.98438
# Iter 149760, Minibatch Loss= 196.806061, Training Accuracy= 0.97656
# Iter 151040, Minibatch Loss= 182.730225, Training Accuracy= 0.95312
# Iter 152320, Minibatch Loss= 258.197083, Training Accuracy= 0.98438
# Iter 153600, Minibatch Loss= 437.212891, Training Accuracy= 0.96875
# Iter 154880, Minibatch Loss= 59.536819, Training Accuracy= 0.97656
# Iter 156160, Minibatch Loss= 533.224548, Training Accuracy= 0.93750
# Iter 157440, Minibatch Loss= 270.223480, Training Accuracy= 0.96875
# Iter 158720, Minibatch Loss= 45.901863, Training Accuracy= 0.98438
# Iter 160000, Minibatch Loss= 48.689919, Training Accuracy= 0.98438
# Iter 161280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 162560, Minibatch Loss= 266.571320, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 106.421173, Training Accuracy= 0.96875
# Iter 165120, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 166400, Minibatch Loss= 58.360352, Training Accuracy= 0.98438
# Iter 167680, Minibatch Loss= 32.113152, Training Accuracy= 0.98438
# Iter 168960, Minibatch Loss= 37.468338, Training Accuracy= 0.98438
# Iter 170240, Minibatch Loss= 287.699463, Training Accuracy= 0.94531
# Iter 171520, Minibatch Loss= 57.683487, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 69.757393, Training Accuracy= 0.98438
# Iter 174080, Minibatch Loss= 15.955513, Training Accuracy= 0.98438
# Iter 175360, Minibatch Loss= 210.587677, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 218.766190, Training Accuracy= 0.96094
# Iter 177920, Minibatch Loss= 70.609749, Training Accuracy= 0.99219
# Iter 179200, Minibatch Loss= 231.702560, Training Accuracy= 0.97656
# Iter 180480, Minibatch Loss= 173.495529, Training Accuracy= 0.98438
# Iter 181760, Minibatch Loss= 134.723389, Training Accuracy= 0.96875
# Iter 183040, Minibatch Loss= 96.454727, Training Accuracy= 0.99219
# Iter 184320, Minibatch Loss= 41.587036, Training Accuracy= 0.99219
# Iter 185600, Minibatch Loss= 137.274292, Training Accuracy= 0.97656
# Iter 186880, Minibatch Loss= 144.609543, Training Accuracy= 0.98438
# Iter 188160, Minibatch Loss= 89.644592, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 320.745117, Training Accuracy= 0.97656
# Iter 190720, Minibatch Loss= 240.678009, Training Accuracy= 0.96094
# Iter 192000, Minibatch Loss= 296.370300, Training Accuracy= 0.96875
# Iter 193280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 194560, Minibatch Loss= 105.158066, Training Accuracy= 0.96875
# Iter 195840, Minibatch Loss= 72.266830, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 155.484146, Training Accuracy= 0.97656
# Iter 198400, Minibatch Loss= 275.473145, Training Accuracy= 0.96875
# Iter 199680, Minibatch Loss= 158.317657, Training Accuracy= 0.97656
# Optimization Finished!
# Testing Accuracy: 0.96875
